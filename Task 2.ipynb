# %% [markdown]
# MAIN FLOW SERVICES AND TECHNOLOGIES
#
# DATA SCIENCE WITH PYTHON
#
# INTERNSHIP BATCH: 25 MAY - 25 JULY 2024
#
#     NAME- SAKSHI RAJESH BHAVSAR
#     EMAIL- bsakshi2019@gmail.com
#
#                                                         **TASK 2**

# %% [markdown]
# Data Manipulation with python pandas
# # Description: This task involves using the Pandas library to manipulate data.
#
# ## Responsibility: Load a CSV file into a Pandas DataFrame. Perform operations like filtering data based on conditions, handling missing values, and calculating summary statistics.

# %% [markdown]
# # Step 1: Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Step 2: Load the Data
# Load the CSV file into a Pandas DataFrame.

# %%
# Load the CSV file into a Pandas DataFrame
data = pd.read_csv('01.Data Cleaning and Preprocessing.csv')

# Display the first few rows of the DataFrame
data
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info
# Out:
# <bound method DataFrame.info of     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1      31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2      31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3      31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4      31-04:00    22.90    15.618      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 319    10-16:00    23.75    12.667      93.450  1178.252      276.955
# 320     9-19:00    19.80    12.558      94.352  1184.119      297.071
# 321     9-20:00    23.01    12.550      90.842  1188.517      289.826
# 322     9-21:00    24.32    13.083      88.910  1192.879      318.006
# 323     9-22:00    25.75    13.417      85.451  1186.342      248.312
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %% [markdown]
# # Step 3: Remove Duplicate Rows
# Identify and remove duplicate rows from the DataFrame.

# %%
# Remove duplicate rows
data_no_duplicates = data.drop_duplicates()

# Display the DataFrame after removing duplicates
data_no_duplicates.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443       599.253  ...        67.122
# 1        351.050         329.067  1.549       537.201  ...        60.012
# 2        350.022         329.260  1.600       549.611  ...        61.304
# 3        350.938         331.142  1.604       623.362  ...        68.496
# 4        351.640         332.709    NaN       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %% [markdown]
# # Step 4: Handle Missing Values
# Identify missing values and handle them. One common approach is to fill missing values with the mean of the respective columns.

# %%
data_no_duplicates.isnull()
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0          False    False     False       False     False        False
# 1          False    False     False       False     False        False
# 2          False    False     False       False     False        False
# 3          False    False     False       False     False        False
# 4          False    False     False       False     False        False
# ..           ...      ...       ...         ...       ...          ...
# 298        False    False     False       False     False        False
# 299        False    False      True       False     False        False
# 300        False    False      True       False     False        False
# 301        False    False      True       False     False        False
# 307        False    False     False       False     False        False
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
# Check for missing values
data_no_duplicates.isnull().sum()
# Out:
# Observation          0
# Y-Kappa              0
# ChipRate             4
# BF-CMratio          14
# BlowFlow            13
# ChipLevel4           1
# T-upperExt-2         1
# T-lowerExt-2         1
# UCZAA               24
# WhiteFlow-4          1
# AAWhiteSt-4        141
# AA-Wood-4            1
# ChipMoisture-4       1
# SteamFlow-4          1
# Lower-HeatT-3        1
# Upper-HeatT-3        1
# ChipMass-4           1
# WeakLiquorF          1
# BlackFlow-2          1
# WeakWashF            1
# SteamHeatF-3         1
# T-Top-Chips-4        1
# SulphidityL-4      141
# dtype: int64

# %%
# Fill missing values with the mean of their respective columns
data_filled = data_no_duplicates.fillna(data_no_duplicates.mean(numeric_only=True))

# Display the DataFrame after filling missing values
data_filled.head()
# Out:
#   Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0    31-00:00    23.10    16.520     121.717  1177.607      169.805
# 1    31-01:00    27.60    16.810      79.022  1328.360      341.327
# 2    31-02:00    23.19    16.709      79.562  1329.407      239.161
# 3    31-03:00    23.60    16.478      81.011  1334.877      213.527
# 4    31-04:00    22.90    15.618      93.244  1334.168      243.131
#
#    T-upperExt-2   T-lowerExt-2       UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# 0        358.282         329.545  1.443000       599.253  ...        67.122
# 1        351.050         329.067  1.549000       537.201  ...        60.012
# 2        350.022         329.260  1.600000       549.611  ...        61.304
# 3        350.938         331.142  1.604000       623.362  ...        68.496
# 4        351.640         332.709  1.490588       638.672  ...        70.022
#
#    Lower-HeatT-3  Upper-HeatT-3   ChipMass-4   WeakLiquorF   BlackFlow-2   \
# ...

# %%
# Check for missing values after filling
data_filled.isnull().sum()
# Out:
# Observation        0
# Y-Kappa            0
# ChipRate           0
# BF-CMratio         0
# BlowFlow           0
# ChipLevel4         0
# T-upperExt-2       0
# T-lowerExt-2       0
# UCZAA              0
# WhiteFlow-4        0
# AAWhiteSt-4        0
# AA-Wood-4          0
# ChipMoisture-4     0
# SteamFlow-4        0
# Lower-HeatT-3      0
# Upper-HeatT-3      0
# ChipMass-4         0
# WeakLiquorF        0
# BlackFlow-2        0
# WeakWashF          0
# SteamHeatF-3       0
# T-Top-Chips-4      0
# SulphidityL-4      0
# dtype: int64

# %%
data_filled.notnull()
# Out:
#      Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0           True     True      True        True      True         True
# 1           True     True      True        True      True         True
# 2           True     True      True        True      True         True
# 3           True     True      True        True      True         True
# 4           True     True      True        True      True         True
# ..           ...      ...       ...         ...       ...          ...
# 298         True     True      True        True      True         True
# 299         True     True      True        True      True         True
# 300         True     True      True        True      True         True
# 301         True     True      True        True      True         True
# 307         True     True      True        True      True         True
#
#      T-upperExt-2   T-lowerExt-2    UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...

# %%
data_filled.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# # Step 5: Calculate Summary Statistics
# Calculate and display summary statistics to understand the distribution of the numerical data.

# %%
# Calculate summary statistics for the numerical columns
summary_statistics = data_filled.describe()

# Display the summary statistics
summary_statistics
# Out:
#           Y-Kappa    ChipRate  BF-CMratio     BlowFlow  ChipLevel4   \
# count  301.000000  301.000000  301.000000   301.000000   301.000000
# mean    20.568605   14.338670   87.271564  1235.537278   259.365993
# std      2.990751    1.480153    7.654578    99.788084    85.501080
# min     12.170000    9.983000   68.645000     0.000000     0.000000
# 25%     18.450000   13.367000   82.027000  1197.775000   215.485000
# 50%     20.740000   14.338670   87.057000  1254.380000   271.792000
# 75%     23.000000   15.483000   91.957000  1288.104000   320.890000
# max     27.600000   16.958000  121.717000  1351.240000   419.014000
#
#        T-upperExt-2   T-lowerExt-2         UCZAA  WhiteFlow-4   AAWhiteSt-4   \
# count     301.000000      301.000000  301.000000    301.000000    301.000000
# mean      356.907033      324.010783    1.490588    593.148090      6.143012
# std         8.939520        7.637741    0.103722     66.838056      0.059985
# ...

# %% [markdown]
# # Step 6: Display the Cleaned Dataset
# Finally, display the cleaned dataset.

# %%
# Display the cleaned DataFrame
cleaned_data=df_filled
cleaned_data
# Out:
#     Observation  Y-Kappa  ChipRate  BF-CMratio  BlowFlow  ChipLevel4   \
# 0      31-00:00    23.10  16.52000     121.717  1177.607      169.805
# 1      31-01:00    27.60  16.81000      79.022  1328.360      341.327
# 2      31-02:00    23.19  16.70900      79.562  1329.407      239.161
# 3      31-03:00    23.60  16.47800      81.011  1334.877      213.527
# 4      31-04:00    22.90  15.61800      93.244  1334.168      243.131
# ..          ...      ...       ...         ...       ...          ...
# 298    12-09:00    20.90  15.16700      84.640  1283.706      339.440
# 299    12-10:00    24.98  14.33867      85.034  1278.345      368.564
# 300    12-11:00    21.00  14.33867      88.013  1307.722      278.842
# 301    12-12:00    21.40  14.33867      85.490  1255.986      273.484
# 307    31-05:00    20.89  14.30800      94.172  1327.832      251.120
#
#      T-upperExt-2   T-lowerExt-2       UCZAA  WhiteFlow-4   ...  SteamFlow-4   \
# ...
